# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 200)

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_csv("../datasets/raw/IndianWeatherRepository.csv")

print("Dataset Loaded Successfully")
# Out:
# Dataset Loaded Successfully

# %% [markdown]
# # Basic Verification

# %%
print("Shape:", df.shape)
# Out:
# Shape: (119398, 42)

# %% [markdown]
# # First 5 Rows

# %%
df.head()
# Out:
#   country location_name          region  latitude  longitude      timezone  last_updated_epoch    last_updated  temperature_celsius  temperature_fahrenheit condition_text  wind_mph  wind_kph  \
# 0   India    Ashoknagar  Madhya Pradesh     24.57      77.72  Asia/Kolkata          1693286100  29-08-23 10:45                 27.5                    81.5  Partly cloudy      12.8      20.5
# 1   India        Raisen  Madhya Pradesh     23.33      77.80  Asia/Kolkata          1693286100  29-08-23 10:45                 27.5                    81.5          Sunny       9.6      15.5
# 2   India    Chhindwara  Madhya Pradesh     22.07      78.93  Asia/Kolkata          1693286100  29-08-23 10:45                 26.3                    79.3  Partly cloudy      11.4      18.4
# 3   India         Betul  Madhya Pradesh     21.86      77.93  Asia/Kolkata          1693286100  29-08-23 10:45                 25.6                    78.1         Cloudy      10.5      16.9
# 4   India   Hoshangabad  Madhya Pradesh     22.75      77.72  Asia/Kolkata          1693286100  29-08-23 10:45                 27.2                    81.0         Cloudy      10.1      16.2
#
#    wind_degree wind_direction  pressure_mb  pressure_in  precip_mm  precip_in  humidity  cloud  feels_like_celsius  feels_like_fahrenheit  visibility_km  visibility_miles  uv_index  gust_mph  \
# 0          281            WNW         1008        29.77        0.0        0.0        67     26                29.7                   85.5           10.0                 6         7      14.8
# 1          287            WNW         1008        29.78        0.0        0.0        70     19                30.0                   86.0           10.0                 6         7      11.2
# 2          317             NW         1009        29.78        0.0        0.0        70     51                28.2                   82.8           10.0                 6         7      13.2
# 3          297            WNW         1009        29.80        0.0        0.0        76     65                27.6                   81.7           10.0                 6         6      13.0
# 4          274              W         1009        29.79        0.0        0.0        74     82                29.9                   85.8           10.0                 6         6      11.6
#
#    gust_kph  air_quality_Carbon_Monoxide  air_quality_Ozone  air_quality_Nitrogen_dioxide  air_quality_Sulphur_dioxide  air_quality_PM2.5  air_quality_PM10  air_quality_us-epa-index  \
# 0      23.8                        243.7               45.8                           1.7                          3.1               12.6              18.5                         1
# 1      18.0                        240.3               38.3                           2.1                          2.6               10.7              14.2                         1
# 2      21.2                        220.3               57.2                           0.6                          1.7               16.8              20.7                         2
# 3      20.9                        200.3               25.0                           1.2                          1.1                4.9               6.6                         1
# 4      18.7                        257.0               30.8                           2.2                          1.8               11.4              14.8                         1
#
#    air_quality_gb-defra-index  sunrise   sunset moonrise  moonset      moon_phase  moon_illumination
# 0                           2  5:59 AM  6:41 PM  5:42 PM  3:38 AM  Waxing Gibbous                 93
# 1                           1  6:00 AM  6:40 PM  5:39 PM  3:41 AM  Waxing Gibbous                 93
# 2                           2  5:56 AM  6:34 PM  5:32 PM  3:39 AM  Waxing Gibbous                 93
# 3                           1  6:00 AM  6:38 PM  5:36 PM  3:43 AM  Waxing Gibbous                 93
# 4                           1  6:01 AM  6:39 PM  5:38 PM  3:42 AM  Waxing Gibbous                 93

# %% [markdown]
# # Column Names

# %%
df.columns.tolist()
# Out:
# ['country',
#  'location_name',
#  'region',
#  'latitude',
#  'longitude',
#  'timezone',
#  'last_updated_epoch',
#  'last_updated',
#  'temperature_celsius',
#  'temperature_fahrenheit',
#  'condition_text',
#  'wind_mph',
#  'wind_kph',
#  'wind_degree',
#  'wind_direction',
#  'pressure_mb',
#  'pressure_in',
#  'precip_mm',
#  'precip_in',
#  'humidity',
#  'cloud',
#  'feels_like_celsius',
#  'feels_like_fahrenheit',
#  'visibility_km',
#  'visibility_miles',
#  'uv_index',
#  'gust_mph',
#  'gust_kph',
#  'air_quality_Carbon_Monoxide',
#  'air_quality_Ozone',
#  'air_quality_Nitrogen_dioxide',
#  'air_quality_Sulphur_dioxide',
#  'air_quality_PM2.5',
#  'air_quality_PM10',
#  'air_quality_us-epa-index',
#  'air_quality_gb-defra-index',
#  'sunrise',
#  'sunset',
#  'moonrise',
#  'moonset',
#  'moon_phase',
#  'moon_illumination']

# %% [markdown]
# # Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 119398 entries, 0 to 119397
# Data columns (total 42 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   country                       119398 non-null  str
#  1   location_name                 119398 non-null  str
#  2   region                        119398 non-null  str
#  3   latitude                      119398 non-null  float64
#  4   longitude                     119398 non-null  float64
#  5   timezone                      119398 non-null  str
#  6   last_updated_epoch            119398 non-null  int64
#  7   last_updated                  119398 non-null  str
#  8   temperature_celsius           119398 non-null  float64
#  9   temperature_fahrenheit        119398 non-null  float64
#  10  condition_text                119398 non-null  str
#  11  wind_mph                      119398 non-null  float64
#  12  wind_kph                      119398 non-null  float64
#  13  wind_degree                   119398 non-null  int64
#  14  wind_direction                119398 non-null  str
#  15  pressure_mb                   119398 non-null  int64
#  16  pressure_in                   119398 non-null  float64
#  17  precip_mm                     119398 non-null  float64
#  18  precip_in                     119398 non-null  float64
#  19  humidity                      119398 non-null  int64
#  20  cloud                         119398 non-null  int64
#  21  feels_like_celsius            119398 non-null  float64
#  22  feels_like_fahrenheit         119398 non-null  float64
#  23  visibility_km                 119398 non-null  float64
#  24  visibility_miles              119398 non-null  int64
#  25  uv_index                      119398 non-null  int64
#  26  gust_mph                      119398 non-null  float64
#  27  gust_kph                      119398 non-null  float64
#  28  air_quality_Carbon_Monoxide   119398 non-null  float64
#  29  air_quality_Ozone             119398 non-null  float64
#  30  air_quality_Nitrogen_dioxide  119398 non-null  float64
#  31  air_quality_Sulphur_dioxide   119398 non-null  float64
#  32  air_quality_PM2.5             119398 non-null  float64
#  33  air_quality_PM10              119398 non-null  float64
#  34  air_quality_us-epa-index      119398 non-null  int64
#  35  air_quality_gb-defra-index    119398 non-null  int64
#  36  sunrise                       119398 non-null  str
#  37  sunset                        119398 non-null  str
#  38  moonrise                      119398 non-null  str
#  39  moonset                       119398 non-null  str
#  40  moon_phase                    119398 non-null  str
#  41  moon_illumination             119398 non-null  int64
# dtypes: float64(20), int64(10), str(12)
# memory usage: 38.3 MB
