# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 200)
df = pd.read_csv("../datasets/raw/IndianWeatherRepository.csv")
print("Dataset Loaded Successfully")
# Out:
# Dataset Loaded Successfully

# %% [markdown]
# # Dataset Shape

# %%
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
# Out:
# Rows: 119398
# Columns: 42

# %% [markdown]
# # Missing Value Analysis

# %%
missing_values = df.isnull().sum()
missing_report = pd.DataFrame({
    "Column": df.columns,
    "Missing Values": missing_values.values
})
missing_report
# Out:
#                           Column  Missing Values
# 0                        country               0
# 1                  location_name               0
# 2                         region               0
# 3                       latitude               0
# 4                      longitude               0
# 5                       timezone               0
# 6             last_updated_epoch               0
# 7                   last_updated               0
# 8            temperature_celsius               0
# 9         temperature_fahrenheit               0
# 10                condition_text               0
# 11                      wind_mph               0
# 12                      wind_kph               0
# 13                   wind_degree               0
# 14                wind_direction               0
# 15                   pressure_mb               0
# 16                   pressure_in               0
# 17                     precip_mm               0
# ...

# %% [markdown]
# # Total Missing Values

# %%
total_missing = df.isnull().sum().sum()
print("Total Missing Values:", total_missing)
# Out:
# Total Missing Values: 0

# %% [markdown]
# # Duplicate Analysis

# %%
duplicates = df.duplicated().sum()
print("Duplicate Records:", duplicates)
# Out:
# Duplicate Records: 0

# %% [markdown]
# # Unique Value Analysis

# %%
unique_values = pd.DataFrame({
    "Column": df.columns,
    "Unique Values": df.nunique().values
})
unique_values.sort_values(
    by="Unique Values"
)
# Out:
#                           Column  Unique Values
# 0                        country              1
# 5                       timezone              3
# 34      air_quality_us-epa-index              6
# 24              visibility_miles              7
# 40                    moon_phase              8
# 25                      uv_index              9
# 35    air_quality_gb-defra-index             10
# 14                wind_direction             16
# 2                         region             33
# 23                 visibility_km             44
# 10                condition_text             50
# 18                     precip_in             72
# 15                   pressure_mb             72
# 41             moon_illumination             92
# 19                      humidity             93
# 20                         cloud            101
# 11                      wind_mph            103
# 12                      wind_kph            103
# 16                   pressure_in            173
# ...

# %% [markdown]
# # Constant Feature Detection

# %%
constant_features = [
    col
    for col in df.columns
    if df[col].nunique() == 1
]
print("Constant Features:")
print(constant_features)
# Out:
# Constant Features:
# ['country']

# %% [markdown]
# # Data Quality Report

# %%
print("""
DATA QUALITY REPORT
1. Missing Values: 0
2. Duplicate Records: 0
3. Dataset integrity verified
4. Constant features detected:
   - country
5. Dataset quality is excellent
6. No imputation required
7. No duplicate removal required
Dataset is ready for feature removal phase.
""")
# Out:
# DATA QUALITY REPORT
# 1. Missing Values: 0
# 2. Duplicate Records: 0
# 3. Dataset integrity verified
# 4. Constant features detected:
#    - country
# 5. Dataset quality is excellent
# 6. No imputation required
# 7. No duplicate removal required
# Dataset is ready for feature removal phase.
