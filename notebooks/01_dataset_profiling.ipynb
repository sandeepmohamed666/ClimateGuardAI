# %% [markdown]
# # Import Libraries and Load Dataset

# %%
import pandas as pd

import numpy as np

pd.set_option("display.max_columns", None)

df = pd.read_csv("../datasets/raw/IndianWeatherRepository.csv")

df.head()
# Out:
#   country location_name          region  latitude  longitude      timezone  \
# 0   India    Ashoknagar  Madhya Pradesh     24.57      77.72  Asia/Kolkata
# 1   India        Raisen  Madhya Pradesh     23.33      77.80  Asia/Kolkata
# 2   India    Chhindwara  Madhya Pradesh     22.07      78.93  Asia/Kolkata
# 3   India         Betul  Madhya Pradesh     21.86      77.93  Asia/Kolkata
# 4   India   Hoshangabad  Madhya Pradesh     22.75      77.72  Asia/Kolkata
#
#    last_updated_epoch    last_updated  temperature_celsius  \
# 0          1693286100  29-08-23 10:45                 27.5
# 1          1693286100  29-08-23 10:45                 27.5
# 2          1693286100  29-08-23 10:45                 26.3
# 3          1693286100  29-08-23 10:45                 25.6
# 4          1693286100  29-08-23 10:45                 27.2
#
#    temperature_fahrenheit condition_text  wind_mph  wind_kph  wind_degree  \
# 0                    81.5  Partly cloudy      12.8      20.5          281
# 1                    81.5          Sunny       9.6      15.5          287
# 2                    79.3  Partly cloudy      11.4      18.4          317
# 3                    78.1         Cloudy      10.5      16.9          297
# 4                    81.0         Cloudy      10.1      16.2          274
#
#   wind_direction  pressure_mb  pressure_in  precip_mm  precip_in  humidity  \
# 0            WNW         1008        29.77        0.0        0.0        67
# 1            WNW         1008        29.78        0.0        0.0        70
# 2             NW         1009        29.78        0.0        0.0        70
# 3            WNW         1009        29.80        0.0        0.0        76
# 4              W         1009        29.79        0.0        0.0        74
#
#    cloud  feels_like_celsius  feels_like_fahrenheit  visibility_km  \
# 0     26                29.7                   85.5           10.0
# 1     19                30.0                   86.0           10.0
# 2     51                28.2                   82.8           10.0
# 3     65                27.6                   81.7           10.0
# 4     82                29.9                   85.8           10.0
#
#    visibility_miles  uv_index  gust_mph  gust_kph  \
# 0                 6         7      14.8      23.8
# 1                 6         7      11.2      18.0
# 2                 6         7      13.2      21.2
# 3                 6         6      13.0      20.9
# 4                 6         6      11.6      18.7
#
#    air_quality_Carbon_Monoxide  air_quality_Ozone  \
# 0                        243.7               45.8
# 1                        240.3               38.3
# 2                        220.3               57.2
# 3                        200.3               25.0
# 4                        257.0               30.8
#
#    air_quality_Nitrogen_dioxide  air_quality_Sulphur_dioxide  \
# 0                           1.7                          3.1
# 1                           2.1                          2.6
# 2                           0.6                          1.7
# 3                           1.2                          1.1
# 4                           2.2                          1.8
#
#    air_quality_PM2.5  air_quality_PM10  air_quality_us-epa-index  \
# 0               12.6              18.5                         1
# 1               10.7              14.2                         1
# 2               16.8              20.7                         2
# 3                4.9               6.6                         1
# 4               11.4              14.8                         1
#
#    air_quality_gb-defra-index  sunrise   sunset moonrise  moonset  \
# 0                           2  5:59 AM  6:41 PM  5:42 PM  3:38 AM
# 1                           1  6:00 AM  6:40 PM  5:39 PM  3:41 AM
# 2                           2  5:56 AM  6:34 PM  5:32 PM  3:39 AM
# 3                           1  6:00 AM  6:38 PM  5:36 PM  3:43 AM
# 4                           1  6:01 AM  6:39 PM  5:38 PM  3:42 AM
#
#        moon_phase  moon_illumination
# 0  Waxing Gibbous                 93
# 1  Waxing Gibbous                 93
# 2  Waxing Gibbous                 93
# 3  Waxing Gibbous                 93
# 4  Waxing Gibbous                 93

# %% [markdown]
# # Dataset Preview & Shape Analysis

# %%
print("Shape:", df.shape)

print("\nRows:", df.shape[0])

print("Columns:", df.shape[1])
# Out:
# Shape: (119398, 42)
#
# Rows: 119398
# Columns: 42

# %% [markdown]
# # Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 119398 entries, 0 to 119397
# Data columns (total 42 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   country                       119398 non-null  str
#  1   location_name                 119398 non-null  str
#  2   region                        119398 non-null  str
#  3   latitude                      119398 non-null  float64
#  4   longitude                     119398 non-null  float64
#  5   timezone                      119398 non-null  str
#  6   last_updated_epoch            119398 non-null  int64
#  7   last_updated                  119398 non-null  str
#  8   temperature_celsius           119398 non-null  float64
#  9   temperature_fahrenheit        119398 non-null  float64
#  10  condition_text                119398 non-null  str
#  11  wind_mph                      119398 non-null  float64
#  12  wind_kph                      119398 non-null  float64
#  13  wind_degree                   119398 non-null  int64
#  14  wind_direction                119398 non-null  str
#  15  pressure_mb                   119398 non-null  int64
#  16  pressure_in                   119398 non-null  float64
#  17  precip_mm                     119398 non-null  float64
#  18  precip_in                     119398 non-null  float64
#  19  humidity                      119398 non-null  int64
#  20  cloud                         119398 non-null  int64
#  21  feels_like_celsius            119398 non-null  float64
#  22  feels_like_fahrenheit         119398 non-null  float64
#  23  visibility_km                 119398 non-null  float64
#  24  visibility_miles              119398 non-null  int64
#  25  uv_index                      119398 non-null  int64
#  26  gust_mph                      119398 non-null  float64
#  27  gust_kph                      119398 non-null  float64
#  28  air_quality_Carbon_Monoxide   119398 non-null  float64
#  29  air_quality_Ozone             119398 non-null  float64
#  30  air_quality_Nitrogen_dioxide  119398 non-null  float64
#  31  air_quality_Sulphur_dioxide   119398 non-null  float64
#  32  air_quality_PM2.5             119398 non-null  float64
#  33  air_quality_PM10              119398 non-null  float64
#  34  air_quality_us-epa-index      119398 non-null  int64
#  35  air_quality_gb-defra-index    119398 non-null  int64
#  36  sunrise                       119398 non-null  str
#  37  sunset                        119398 non-null  str
#  38  moonrise                      119398 non-null  str
#  39  moonset                       119398 non-null  str
#  40  moon_phase                    119398 non-null  str
#  41  moon_illumination             119398 non-null  int64
# dtypes: float64(20), int64(10), str(12)
# memory usage: 38.3 MB

# %% [markdown]
# # Data Type Analysis

# %%
df.dtypes
# Out:
# country                             str
# location_name                       str
# region                              str
# latitude                        float64
# longitude                       float64
# timezone                            str
# last_updated_epoch                int64
# last_updated                        str
# temperature_celsius             float64
# temperature_fahrenheit          float64
# condition_text                      str
# wind_mph                        float64
# wind_kph                        float64
# wind_degree                       int64
# wind_direction                      str
# pressure_mb                       int64
# pressure_in                     float64
# precip_mm                       float64
# precip_in                       float64
# humidity                          int64
# cloud                             int64
# feels_like_celsius              float64
# feels_like_fahrenheit           float64
# visibility_km                   float64
# visibility_miles                  int64
# uv_index                          int64
# gust_mph                        float64
# gust_kph                        float64
# air_quality_Carbon_Monoxide     float64
# air_quality_Ozone               float64
# air_quality_Nitrogen_dioxide    float64
# air_quality_Sulphur_dioxide     float64
# air_quality_PM2.5               float64
# air_quality_PM10                float64
# air_quality_us-epa-index          int64
# air_quality_gb-defra-index        int64
# sunrise                             str
# sunset                              str
# moonrise                            str
# moonset                             str
# moon_phase                          str
# moon_illumination                 int64
# dtype: object

# %% [markdown]
# # Missing Value Analysis

# %%
df.isnull().sum()
# Out:
# country                         0
# location_name                   0
# region                          0
# latitude                        0
# longitude                       0
# timezone                        0
# last_updated_epoch              0
# last_updated                    0
# temperature_celsius             0
# temperature_fahrenheit          0
# condition_text                  0
# wind_mph                        0
# wind_kph                        0
# wind_degree                     0
# wind_direction                  0
# pressure_mb                     0
# pressure_in                     0
# precip_mm                       0
# precip_in                       0
# humidity                        0
# cloud                           0
# feels_like_celsius              0
# feels_like_fahrenheit           0
# visibility_km                   0
# visibility_miles                0
# uv_index                        0
# gust_mph                        0
# gust_kph                        0
# air_quality_Carbon_Monoxide     0
# air_quality_Ozone               0
# air_quality_Nitrogen_dioxide    0
# air_quality_Sulphur_dioxide     0
# air_quality_PM2.5               0
# air_quality_PM10                0
# air_quality_us-epa-index        0
# air_quality_gb-defra-index      0
# sunrise                         0
# sunset                          0
# moonrise                        0
# moonset                         0
# moon_phase                      0
# moon_illumination               0
# dtype: int64

# %% [markdown]
# # Duplicate Record Analysis

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Descriptive Statistics

# %%
df.describe()
# Out:
#             latitude      longitude  last_updated_epoch  temperature_celsius  \
# count  119398.000000  119398.000000        1.193980e+05        119398.000000
# mean       23.099620      80.246300        1.702939e+09            20.303723
# std         5.791228       5.763446        5.659113e+06             6.538599
# min         7.170000      68.970000        1.693286e+09           -30.700000
# 25%        20.270000      76.070000        1.697921e+09            16.600000
# 50%        23.950000      78.690000        1.703098e+09            21.200000
# 75%        26.770000      83.900000        1.707760e+09            24.900000
# max        34.570000      95.800000        1.718557e+09            42.800000
#
#        temperature_fahrenheit       wind_mph       wind_kph    wind_degree  \
# count            119398.00000  119398.000000  119398.000000  119398.000000
# mean                 68.54687       5.024552       8.090798     157.507044
# std                  11.76929       2.825159       4.538947     115.412587
# min                 -23.30000       2.200000       3.600000       1.000000
# 25%                  61.90000       2.700000       4.300000      54.000000
# 50%                  70.20000       4.300000       6.800000     124.000000
# 75%                  76.80000       6.500000      10.400000     272.000000
# max                 109.10000      26.800000      43.200000     360.000000
#
#          pressure_mb    pressure_in      precip_mm      precip_in  \
# count  119398.000000  119398.000000  119398.000000  119398.000000
# mean     1012.828196      29.908350       0.084331       0.003253
# std         4.926352       0.145307       0.608602       0.023960
# min       991.000000      29.280000       0.000000       0.000000
# 25%      1010.000000      29.830000       0.000000       0.000000
# 50%      1013.000000      29.930000       0.000000       0.000000
# 75%      1016.000000      30.000000       0.000000       0.000000
# max      1073.000000      31.690000      43.800000       1.720000
#
#             humidity          cloud  feels_like_celsius  \
# count  119398.000000  119398.000000       119398.000000
# mean       61.582681      23.531600           20.955116
# std        23.619385      29.774276            7.468814
# min         8.000000       0.000000          -36.500000
# 25%        42.000000       1.000000           16.600000
# 50%        63.000000       8.000000           21.200000
# 75%        83.000000      41.000000           26.200000
# max       100.000000     100.000000           50.500000
#
#        feels_like_fahrenheit  visibility_km  visibility_miles       uv_index  \
# count          119398.000000  119398.000000     119398.000000  119398.000000
# mean               69.712328       8.625313          5.086668       1.084742
# std                13.443341       2.794805          1.833549       0.704080
# min               -33.800000       0.000000          0.000000       1.000000
# 25%                61.800000      10.000000          6.000000       1.000000
# 50%                70.200000      10.000000          6.000000       1.000000
# 75%                79.200000      10.000000          6.000000       1.000000
# max               122.900000      10.000000          6.000000       9.000000
#
#             gust_mph       gust_kph  air_quality_Carbon_Monoxide  \
# count  119398.000000  119398.000000                119398.000000
# mean        9.845152      15.844931                   773.096727
# std         4.968244       7.993618                   654.566069
# min         0.000000       0.000000                   113.500000
# 25%         6.100000       9.800000                   413.900000
# 50%         8.900000      14.400000                   580.800000
# 75%        13.000000      20.900000                   921.300000
# max        51.000000      82.200000                 13565.100000
#
#        air_quality_Ozone  air_quality_Nitrogen_dioxide  \
# count      119398.000000                 119398.000000
# mean           43.775466                     14.507559
# std            30.633582                     15.625656
# min             0.000000                      0.000000
# 25%            19.500000                      5.200000
# 50%            39.300000                     10.000000
# 75%            63.700000                     18.900000
# max           243.200000                    318.100000
#
#        air_quality_Sulphur_dioxide  air_quality_PM2.5  air_quality_PM10  \
# count                119398.000000      119398.000000     119398.000000
# mean                      6.650753          92.161884        109.530122
# std                      13.329390          96.278193        108.621703
# min                       0.000000           0.500000          0.500000
# 25%                       1.600000          30.400000         41.200000
# 50%                       3.500000          60.600000         75.600000
# 75%                       7.000000         117.600000        138.500000
# max                     557.000000        1374.800000       1537.800000
#
#        air_quality_us-epa-index  air_quality_gb-defra-index  moon_illumination
# count             119398.000000               119398.000000      119398.000000
# mean                   3.262349                    6.621007          52.458282
# std                    1.412098                    3.489160          34.809059
# min                    1.000000                    1.000000           0.000000
# 25%                    2.000000                    3.000000          18.000000
# 50%                    3.000000                    8.000000          53.000000
# 75%                    4.000000                   10.000000          88.000000
# max                    6.000000                   10.000000         100.000000

# %% [markdown]
# # Categorical Feature Statistics

# %%
df.describe(include="object")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15156\702825166.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include="object")
#        country location_name         region      timezone    last_updated  \
# count   119398        119398         119398        119398          119398
# unique       1           552             33             3             877
# top      India         Nagar  Uttar Pradesh  Asia/Kolkata  04-02-24 23:00
# freq    119398           461          13293        118745             548
#
#        condition_text wind_direction  sunrise   sunset     moonrise  \
# count          119398         119398   119398   119398       119398
# unique             50             16      202      215         1441
# top             Clear              N  6:17 AM  6:01 PM  No moonrise
# freq            47978          12987     1597     1538         4389
#
#            moonset      moon_phase
# count       119398          119398
# unique        1441               8
# top     No moonset  Waning Gibbous
# freq          3836           28478

# %% [markdown]
# # Numerical vs Categorical Feature Segmentation

# %%
numerical_columns = df.select_dtypes(

    include=["int64", "float64"]

).columns

categorical_columns = df.select_dtypes(

    include=["object"]

).columns

print("Numerical Features:", len(numerical_columns))

print("Categorical Features:", len(categorical_columns))
# Out:
# Numerical Features: 30
# Categorical Features: 12
# C:\Users\User\AppData\Local\Temp\ipykernel_15156\1742036862.py:7: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_columns = df.select_dtypes(

# %% [markdown]
# ## Feature Lists

# %%
numerical_columns
# Out:
# Index(['latitude', 'longitude', 'last_updated_epoch', 'temperature_celsius',
#        'temperature_fahrenheit', 'wind_mph', 'wind_kph', 'wind_degree',
#        'pressure_mb', 'pressure_in', 'precip_mm', 'precip_in', 'humidity',
#        'cloud', 'feels_like_celsius', 'feels_like_fahrenheit', 'visibility_km',
#        'visibility_miles', 'uv_index', 'gust_mph', 'gust_kph',
#        'air_quality_Carbon_Monoxide', 'air_quality_Ozone',
#        'air_quality_Nitrogen_dioxide', 'air_quality_Sulphur_dioxide',
#        'air_quality_PM2.5', 'air_quality_PM10', 'air_quality_us-epa-index',
#        'air_quality_gb-defra-index', 'moon_illumination'],
#       dtype='str')

# %%
categorical_columns
# Out:
# Index(['country', 'location_name', 'region', 'timezone', 'last_updated',
#        'condition_text', 'wind_direction', 'sunrise', 'sunset', 'moonrise',
#        'moonset', 'moon_phase'],
#       dtype='str')

# %% [markdown]
# # Dataset Summary Report

# %%
summary = pd.DataFrame({

    "Column": df.columns,

    "Datatype": df.dtypes.values,

    "Missing Values": df.isnull().sum().values,

    "Unique Values": df.nunique().values

})

summary
# Out:
#                           Column Datatype  Missing Values  Unique Values
# 0                        country      str               0              1
# 1                  location_name      str               0            552
# 2                         region      str               0             33
# 3                       latitude  float64               0            455
# 4                      longitude  float64               0            435
# 5                       timezone      str               0              3
# 6             last_updated_epoch    int64               0            432
# 7                   last_updated      str               0            877
# 8            temperature_celsius  float64               0            636
# 9         temperature_fahrenheit  float64               0           1056
# 10                condition_text      str               0             50
# 11                      wind_mph  float64               0            103
# 12                      wind_kph  float64               0            103
# 13                   wind_degree    int64               0            360
# 14                wind_direction      str               0             16
# 15                   pressure_mb    int64               0             72
# 16                   pressure_in  float64               0            173
# 17                     precip_mm  float64               0            534
# 18                     precip_in  float64               0             72
# 19                      humidity    int64               0             93
# 20                         cloud    int64               0            101
# 21            feels_like_celsius  float64               0            695
# 22         feels_like_fahrenheit  float64               0           1162
# 23                 visibility_km  float64               0             44
# 24              visibility_miles    int64               0              7
# 25                      uv_index    int64               0              9
# 26                      gust_mph  float64               0            363
# 27                      gust_kph  float64               0            554
# 28   air_quality_Carbon_Monoxide  float64               0            416
# 29             air_quality_Ozone  float64               0            384
# 30  air_quality_Nitrogen_dioxide  float64               0            391
# 31   air_quality_Sulphur_dioxide  float64               0            409
# 32             air_quality_PM2.5  float64               0           5078
# 33              air_quality_PM10  float64               0           5561
# 34      air_quality_us-epa-index    int64               0              6
# 35    air_quality_gb-defra-index    int64               0             10
# 36                       sunrise      str               0            202
# 37                        sunset      str               0            215
# 38                      moonrise      str               0           1441
# 39                       moonset      str               0           1441
# 40                    moon_phase      str               0              8
# 41             moon_illumination    int64               0             92
